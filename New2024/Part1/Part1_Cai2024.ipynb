# %%
import scanpy as sc
import omicverse as ov
ov.plot_set()
# Out:
#    ____            _     _    __
#   / __ \____ ___  (_)___| |  / /__  _____________
#  / / / / __ `__ \/ / ___/ | / / _ \/ ___/ ___/ _ \
# / /_/ / / / / / / / /__ | |/ /  __/ /  (__  )  __/
# \____/_/ /_/ /_/_/\___/ |___/\___/_/  /____/\___/
#
# Version: 1.6.11, Tutorials: https://omicverse.readthedocs.io/
# Dependency error: The 'phate>=1.0' distribution was not found and is required by the application

# %%
# !ls /home/lugli/spuccio/Projects/SP039/New_2024/Cai2024/GSE271379_RAW
# Out:
# GSM8375832  GSM8375833	GSM8375834  GSM8375835	GSM8375836

# %%
GSM8375832 =sc.read_10x_mtx("/home/lugli/spuccio/Projects/SP039/New_2024/Cai2024/GSE271379_RAW/GSM8375832")
GSM8375833 =sc.read_10x_mtx("/home/lugli/spuccio/Projects/SP039/New_2024/Cai2024/GSE271379_RAW/GSM8375833")
GSM8375834 =sc.read_10x_mtx("/home/lugli/spuccio/Projects/SP039/New_2024/Cai2024/GSE271379_RAW/GSM8375834")
GSM8375835 =sc.read_10x_mtx("/home/lugli/spuccio/Projects/SP039/New_2024/Cai2024/GSE271379_RAW/GSM8375835")
GSM8375836 =sc.read_10x_mtx("/home/lugli/spuccio/Projects/SP039/New_2024/Cai2024/GSE271379_RAW/GSM8375836")
# Out:
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.

# %%
GSM8375832.var_names_make_unique()
GSM8375832.obs_names_make_unique()

# %%
GSM8375833.var_names_make_unique()
GSM8375833.obs_names_make_unique()

# %%
GSM8375834.var_names_make_unique()
GSM8375834.obs_names_make_unique()

# %%
GSM8375835.var_names_make_unique()
GSM8375835.obs_names_make_unique()

# %%
GSM8375836.var_names_make_unique()
GSM8375836.obs_names_make_unique()

# %%
# %%time
GSM8375832=ov.pp.qc(GSM8375832,
              tresh={'mito_perc': 0.2, 'nUMIs': 500, 'detected_genes': 250},
               doublets_method='sccomposite',
              batch_key=None)
GSM8375832
# Out:
# CPU mode activated
# Calculate QC metrics
# End calculation of QC metrics.
# Original cell number: 5148
# !!!It should be noted that the `sccomposite` will remove more cells than             `scrublet`!!!
# Begin of post doublets removal and QC plot using `sccomposite`
# Cuda is not available; Fitting the COMPOSITE model on RNA modality
# The RNA modality goodness-of-fit score is: 5.0931992891219915
# <3: poor fit
# 3~5: moderate fit
# >5: good fit
# Cells retained after sccomposite: 3187, 1961 removed.
# End of post sccomposite removal and QC plots.
# Filters application (seurat or mads)
# Lower treshold, nUMIs: 500; filtered-out-cells:         0
# Lower treshold, n genes: 250; filtered-out-cells:         0
# Lower treshold, mito %: 0.2; filtered-out-cells:         35
# Filters applicated.
# Total cell filtered out with this last --mode seurat QC (and its     chosen options): 35
# Cells retained after scrublet and seurat filtering: 3152, 1996 removed.
# ...

# %%
# %%time
GSM8375833=ov.pp.qc(GSM8375833,
              tresh={'mito_perc': 0.2, 'nUMIs': 500, 'detected_genes': 250},
               doublets_method='sccomposite',
              batch_key=None)
GSM8375833
# Out:
# CPU mode activated
# Calculate QC metrics
# End calculation of QC metrics.
# Original cell number: 11473
# !!!It should be noted that the `sccomposite` will remove more cells than             `scrublet`!!!
# Begin of post doublets removal and QC plot using `sccomposite`
# Cuda is not available; Fitting the COMPOSITE model on RNA modality
# The RNA modality goodness-of-fit score is: 6.243041542505492
# <3: poor fit
# 3~5: moderate fit
# >5: good fit
# Cells retained after sccomposite: 6133, 5340 removed.
# End of post sccomposite removal and QC plots.
# Filters application (seurat or mads)
# Lower treshold, nUMIs: 500; filtered-out-cells:         1
# Lower treshold, n genes: 250; filtered-out-cells:         29
# Lower treshold, mito %: 0.2; filtered-out-cells:         274
# Filters applicated.
# Total cell filtered out with this last --mode seurat QC (and its     chosen options): 285
# Cells retained after scrublet and seurat filtering: 5848, 5625 removed.
# ...

# %%
# %%time
GSM8375834=ov.pp.qc(GSM8375834,
              tresh={'mito_perc': 0.2, 'nUMIs': 500, 'detected_genes': 250},
               doublets_method='sccomposite',
              batch_key=None)
GSM8375834
# Out:
# CPU mode activated
# Calculate QC metrics
# End calculation of QC metrics.
# Original cell number: 2584
# !!!It should be noted that the `sccomposite` will remove more cells than             `scrublet`!!!
# Begin of post doublets removal and QC plot using `sccomposite`
# Cuda is not available; Fitting the COMPOSITE model on RNA modality
# ...
# The RNA modality goodness-of-fit score is: 3.304275765082144
# <3: poor fit
# 3~5: moderate fit
# >5: good fit
# Cells retained after sccomposite: 2295, 289 removed.
# End of post sccomposite removal and QC plots.
# Filters application (seurat or mads)
# Lower treshold, nUMIs: 500; filtered-out-cells:         0
# Lower treshold, n genes: 250; filtered-out-cells:         0
# Lower treshold, mito %: 0.2; filtered-out-cells:         0
# Filters applicated.
# Total cell filtered out with this last --mode seurat QC (and its     chosen options): 0
# Cells retained after scrublet and seurat filtering: 2295, 289 removed.
# ...

# %%
# %%time
GSM8375835=ov.pp.qc(GSM8375835,
              tresh={'mito_perc': 0.2, 'nUMIs': 500, 'detected_genes': 250},
               doublets_method='sccomposite',
              batch_key=None)
GSM8375835
# Out:
# CPU mode activated
# Calculate QC metrics
# End calculation of QC metrics.
# Original cell number: 2584
# !!!It should be noted that the `sccomposite` will remove more cells than             `scrublet`!!!
# Begin of post doublets removal and QC plot using `sccomposite`
# Cuda is not available; Fitting the COMPOSITE model on RNA modality
# ...
# The RNA modality goodness-of-fit score is: 3.304275765082144
# <3: poor fit
# 3~5: moderate fit
# >5: good fit
# Cells retained after sccomposite: 2295, 289 removed.
# End of post sccomposite removal and QC plots.
# Filters application (seurat or mads)
# Lower treshold, nUMIs: 500; filtered-out-cells:         0
# Lower treshold, n genes: 250; filtered-out-cells:         0
# Lower treshold, mito %: 0.2; filtered-out-cells:         0
# Filters applicated.
# Total cell filtered out with this last --mode seurat QC (and its     chosen options): 0
# Cells retained after scrublet and seurat filtering: 2295, 289 removed.
# ...

# %%
# %%time
GSM8375835=ov.pp.qc(GSM8375835,
              tresh={'mito_perc': 0.2, 'nUMIs': 500, 'detected_genes': 250},
               doublets_method='sccomposite',
              batch_key=None)
GSM8375836
# Out:
# CPU mode activated
# Calculate QC metrics
# End calculation of QC metrics.
# Original cell number: 2295
# !!!It should be noted that the `sccomposite` will remove more cells than             `scrublet`!!!
# Begin of post doublets removal and QC plot using `sccomposite`
# Cuda is not available; Fitting the COMPOSITE model on RNA modality
# ...
# The RNA modality goodness-of-fit score is: 3.3189677671885054
# <3: poor fit
# 3~5: moderate fit
# >5: good fit
# Cells retained after sccomposite: 2071, 224 removed.
# End of post sccomposite removal and QC plots.
# Filters application (seurat or mads)
# Lower treshold, nUMIs: 500; filtered-out-cells:         0
# Lower treshold, n genes: 250; filtered-out-cells:         0
# Lower treshold, mito %: 0.2; filtered-out-cells:         0
# Filters applicated.
# Total cell filtered out with this last --mode seurat QC (and its     chosen options): 0
# Cells retained after scrublet and seurat filtering: 2071, 224 removed.
# ...

# %%
GSM8375832.obs['author'] = "Cai2024"
GSM8375833.obs['author'] = "Cai2024"
GSM8375834.obs['author'] = "Cai2024"
GSM8375835.obs['author'] = "Cai2024"
GSM8375836.obs['author'] = "Cai2024"

# %%
GSM8375832.obs['donor_id'] = "GSM8375832"
GSM8375833.obs['donor_id'] = "GSM8375833"
GSM8375834.obs['donor_id'] = "GSM8375834"
GSM8375835.obs['donor_id'] = "GSM8375835"
GSM8375836.obs['donor_id'] = "GSM8375836"

# %%
adata = GSM8375836.concatenate([GSM8375832,GSM8375833,GSM8375834,GSM8375835])

# %%
adata.obs
# Out:
#                        nUMIs  mito_perc  detected_genes  cell_complexity  \
# AAACCTGAGACTTTCG-1-0  1749.0   0.129217            1187         0.678674
# AAACCTGAGGCTATCT-1-0  2683.0   0.022363            1697         0.632501
# AAACCTGAGTGCGTGA-1-0  4956.0   0.005851            2478         0.500000
# AAACCTGTCAGGTAAA-1-0  3219.0   0.111215            2083         0.647095
# AAACGGGAGCCCAGCT-1-0  4216.0   0.025142            1803         0.427657
# ...                      ...        ...             ...              ...
# TTTGGTTGTACCTACA-1-4  3351.0   0.066249            1841         0.549388
# TTTGGTTGTGCAGACA-1-4  3693.0   0.070674            2463         0.666937
# TTTGGTTTCTACCAGA-1-4  2089.0   0.077070            1513         0.724270
# TTTGTCACAATGGATA-1-4  1854.0   0.036677            1367         0.737325
# TTTGTCATCGCAAGCC-1-4  2904.0   0.166322            1717         0.591253
#
#                       sccomposite_doublet  sccomposite_consistency  \
# ...

# %%
# %%time
adata=ov.pp.preprocess(adata,mode='shiftlog|pearson',n_HVGs=2000,
                       target_sum=50*1e4)
adata
# Out:
# Begin robust gene identification
# After filtration, 17519/17519 genes are kept.     Among 17519 genes, 17519 genes are robust.
# End of robust gene identification.
# Begin size normalization: shiftlog and HVGs selection pearson
# normalizing counts per cell. The following highly-expressed genes are not considered during normalization factor computation:
# ['IGKC', 'SPP1', 'MALAT1', 'MT2A', 'GFAP', 'CST3', 'FTL']
#     finished (0:00:00)
# extracting highly variable genes
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'highly_variable_rank', float vector (adata.var)
#     'highly_variable_nbatches', int vector (adata.var)
#     'highly_variable_intersection', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'variances', float vector (adata.var)
#     'residual_variances', float vector (adata.var)
# Time to analyze data in cpu: 3.1307356357574463 seconds.
# End of size normalization: shiftlog and HVGs selection pearson
# ...

# %%
X_counts_recovered, size_factors_sub=ov.pp.recover_counts(adata.X, 50*1e4, 50*1e5, log_base=None, 
                                                          chunk_size=10000)
adata.layers['recover_counts']=X_counts_recovered
# Out:
# ...
# 100%|██████████| 5950/5950 [00:07<00:00, 776.14it/s]

# %%
# %%time
adata.raw = adata
adata = adata[:, adata.var.highly_variable_features]
adata
# Out:
# CPU times: user 48.3 ms, sys: 52 ms, total: 100 ms
# Wall time: 98 ms
# View of AnnData object with n_obs × n_vars = 15950 × 2000
#     obs: 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'n_genes', 'author', 'donor_id', 'batch'
#     var: 'gene_ids', 'feature_types', 'mt', 'n_cells-0', 'n_cells-1', 'n_cells-2', 'n_cells-3', 'n_cells-4', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'log1p', 'hvg'
#     layers: 'counts', 'recover_counts'

# %%
# %%time
ov.pp.scale(adata)
adata
# Out:
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# CPU times: user 1.79 s, sys: 220 ms, total: 2.01 s
# Wall time: 1.56 s
# AnnData object with n_obs × n_vars = 15950 × 2000
#     obs: 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'n_genes', 'author', 'donor_id', 'batch'
#     var: 'gene_ids', 'feature_types', 'mt', 'n_cells-0', 'n_cells-1', 'n_cells-2', 'n_cells-3', 'n_cells-4', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'log1p', 'hvg'
#     layers: 'counts', 'recover_counts', 'scaled'

# %%
# %%time
ov.pp.pca(adata,layer='scaled',n_pcs=50)
adata
# Out:
# computing PCA
#     with n_comps=50
#     finished (0:00:02)
# CPU times: user 14.5 s, sys: 30.6 s, total: 45.1 s
# Wall time: 2.2 s
# AnnData object with n_obs × n_vars = 15950 × 2000
#     obs: 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'n_genes', 'author', 'donor_id', 'batch'
#     var: 'gene_ids', 'feature_types', 'mt', 'n_cells-0', 'n_cells-1', 'n_cells-2', 'n_cells-3', 'n_cells-4', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'log1p', 'hvg', 'pca', 'scaled|original|pca_var_ratios', 'scaled|original|cum_sum_eigenvalues'
#     obsm: 'X_pca', 'scaled|original|X_pca'
#     varm: 'PCs', 'scaled|original|pca_loadings'
#     layers: 'counts', 'recover_counts', 'scaled'

# %%
# %%time
ov.pp.neighbors(adata, n_neighbors=15, n_pcs=50,
               use_rep='scaled|original|X_pca')
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:24)
# CPU times: user 24.6 s, sys: 965 ms, total: 25.5 s
# Wall time: 24.2 s

# %%
# %%time
ov.pp.umap(adata)
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm)
#     'umap', UMAP parameters (adata.uns) (0:00:21)
# CPU times: user 1min 9s, sys: 34.9 s, total: 1min 43s
# Wall time: 21.5 s

# %%
ov.pl.embedding(adata,
                basis='X_umap',
                color='CST3',
                frameon='small')

# %%
adata_raw=adata.raw.to_adata()
ov.pp.score_genes_cell_cycle(adata_raw,species='human')
# Out:
# calculating cell cycle phase
# computing score 'S_score'
# WARNING: genes are not in var_names and ignored: Index(['MLF1IP'], dtype='object')
#     finished: added
#     'S_score', score of gene set (adata.obs).
#     686 total control genes are used. (0:00:00)
# computing score 'G2M_score'
#     finished: added
#     'G2M_score', score of gene set (adata.obs).
#     854 total control genes are used. (0:00:00)
# -->     'phase', cell cycle phase (adata.obs)

# %%
ov.pl.embedding(adata_raw,
                basis='X_umap',
                color='phase',
                frameon='small')

# %%
ov.pp.leiden(adata,resolution=1)
# Out:
# running Leiden clustering
#     finished: found 341 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:03)

# %%
ov.pl.embedding(adata,
                basis='X_umap',
                color=['leiden', 'CST3', 'PTPRC'],
                frameon='small',wspace=0.5)
# Out:
# the obs value 'leiden' has more than 103 categories. Uniform 'grey' color will be used for all categories.

# %%
ov.pl.embedding(adata,
                basis='X_umap',
                color=['leiden', 'donor_id'],
                frameon='small',wspace=0.5)

# %%
adata.write("/home/lugli/spuccio/Projects/SP039/GBmap/Cai2024_Part1.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 15950 × 2000
#     obs: 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'n_genes', 'author', 'donor_id', 'batch', 'leiden'
#     var: 'gene_ids', 'feature_types', 'mt', 'n_cells-0', 'n_cells-1', 'n_cells-2', 'n_cells-3', 'n_cells-4', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'log1p', 'hvg', 'pca', 'scaled|original|pca_var_ratios', 'scaled|original|cum_sum_eigenvalues', 'neighbors', 'umap', 'leiden', 'leiden_colors', 'donor_id_colors'
#     obsm: 'X_pca', 'scaled|original|X_pca', 'X_umap'
#     varm: 'PCs', 'scaled|original|pca_loadings'
#     layers: 'counts', 'recover_counts', 'scaled'
#     obsp: 'distances', 'connectivities'
