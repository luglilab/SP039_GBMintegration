# %%
import scanpy as sc
import omicverse as ov
ov.plot_set()
# Out:
#    ____            _     _    __
#   / __ \____ ___  (_)___| |  / /__  _____________
#  / / / / __ `__ \/ / ___/ | / / _ \/ ___/ ___/ _ \
# / /_/ / / / / / / / /__ | |/ /  __/ /  (__  )  __/
# \____/_/ /_/ /_/_/\___/ |___/\___/_/  /____/\___/
#
# Version: 1.6.11, Tutorials: https://omicverse.readthedocs.io/
# Dependency error: The 'phate>=1.0' distribution was not found and is required by the application

# %%
adata = sc.read("/home/lugli/spuccio/Projects/SP039/GBmap/Abdelfattah2022_Part1.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 207377 × 26355
#     obs: 'author', 'donor_id', 'is_primary_data', 'annotation_level_1', 'annotation_level_2', 'annotation_level_3', 'gbmap', 'method', 'stage', 'location', 'EGFR', 'MET', 'p53', 'TERT', 'ATRX', 'PTEN', 'MGMT', 'chr1p19q', 'PDGFR', 'suspension_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'tissue', 'development_stage'
#     uns: 'X_approximate_distribution', 'batch_condition', 'default_embedding', 'hvg', 'schema_version', 'title'
#     obsm: 'X_umap'

# %%
adata.var_names_make_unique()
adata.obs_names_make_unique()

# %%
# %%time
adata=ov.pp.qc(adata,
              tresh={'mito_perc': 0.2, 'nUMIs': 500, 'detected_genes': 250},
               doublets_method='sccomposite',
              batch_key=None)
adata
# Out:
# CPU mode activated
# Calculate QC metrics
# End calculation of QC metrics.
# Original cell number: 207377
# !!!It should be noted that the `sccomposite` will remove more cells than             `scrublet`!!!
# Begin of post doublets removal and QC plot using `sccomposite`
# Cuda is not available; Fitting the COMPOSITE model on RNA modality
# The RNA modality goodness-of-fit score is: 3.891001030629476
# <3: poor fit
# 3~5: moderate fit
# >5: good fit
# Cells retained after sccomposite: 203473, 3904 removed.
# End of post sccomposite removal and QC plots.
# Filters application (seurat or mads)
# Lower treshold, nUMIs: 500; filtered-out-cells:         26
# Lower treshold, n genes: 250; filtered-out-cells:         0
# Lower treshold, mito %: 0.2; filtered-out-cells:         0
# Filters applicated.
# Total cell filtered out with this last --mode seurat QC (and its     chosen options): 26
# Cells retained after scrublet and seurat filtering: 203447, 3930 removed.
# filtered out 7476 genes that are detected in less than 3 cells
# CPU times: user 1d 13h 33min 40s, sys: 8h 44min 17s, total: 1d 22h 17min 57s
# Wall time: 2h 51min 33s
# AnnData object with n_obs × n_vars = 203447 × 18879
#     obs: 'author', 'donor_id', 'is_primary_data', 'annotation_level_1', 'annotation_level_2', 'annotation_level_3', 'gbmap', 'method', 'stage', 'location', 'EGFR', 'MET', 'p53', 'TERT', 'ATRX', 'PTEN', 'MGMT', 'chr1p19q', 'PDGFR', 'suspension_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'tissue', 'development_stage', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'n_genes'
#     var: 'mt', 'n_cells'
#     uns: 'X_approximate_distribution', 'batch_condition', 'default_embedding', 'hvg', 'schema_version', 'title'
#     obsm: 'X_umap'

# %%
# %%time
adata=ov.pp.preprocess(adata,mode='shiftlog|pearson',n_HVGs=2000,
                       target_sum=50*1e4)
adata
# Out:
# Begin robust gene identification
# After filtration, 18879/18879 genes are kept.     Among 18879 genes, 17499 genes are robust.
# End of robust gene identification.
# Begin size normalization: shiftlog and HVGs selection pearson
# normalizing counts per cell. The following highly-expressed genes are not considered during normalization factor computation:
# []
#     finished (0:00:01)
# extracting highly variable genes
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'highly_variable_rank', float vector (adata.var)
#     'highly_variable_nbatches', int vector (adata.var)
#     'highly_variable_intersection', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'variances', float vector (adata.var)
#     'residual_variances', float vector (adata.var)
# Time to analyze data in cpu: 51.402557373046875 seconds.
# End of size normalization: shiftlog and HVGs selection pearson
# CPU times: user 1min 37s, sys: 19.8 s, total: 1min 57s
# Wall time: 1min 7s
# AnnData object with n_obs × n_vars = 203447 × 17499
#     obs: 'author', 'donor_id', 'is_primary_data', 'annotation_level_1', 'annotation_level_2', 'annotation_level_3', 'gbmap', 'method', 'stage', 'location', 'EGFR', 'MET', 'p53', 'TERT', 'ATRX', 'PTEN', 'MGMT', 'chr1p19q', 'PDGFR', 'suspension_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'tissue', 'development_stage', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'n_genes'
#     var: 'mt', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'X_approximate_distribution', 'batch_condition', 'default_embedding', 'hvg', 'schema_version', 'title', 'log1p'
#     obsm: 'X_umap'
#     layers: 'counts'

# %%
X_counts_recovered, size_factors_sub=ov.pp.recover_counts(adata.X, 50*1e4, 50*1e5, log_base=None, 
                                                          chunk_size=10000)
adata.layers['recover_counts']=X_counts_recovered
# Out:
# 100%|██████████| 10000/10000 [00:12<00:00, 797.40it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 793.77it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 817.04it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 816.21it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 816.59it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 773.48it/s]
# 100%|██████████| 10000/10000 [00:13<00:00, 767.89it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 784.97it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 788.18it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 788.38it/s]
# 100%|██████████| 10000/10000 [00:11<00:00, 835.55it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 817.13it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 814.99it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 800.47it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 802.66it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 794.16it/s]
# 100%|██████████| 10000/10000 [00:13<00:00, 762.16it/s]
# 100%|██████████| 10000/10000 [00:13<00:00, 756.33it/s]
# 100%|██████████| 10000/10000 [00:13<00:00, 760.43it/s]
# 100%|██████████| 10000/10000 [00:13<00:00, 760.06it/s]
# 100%|██████████| 3447/3447 [00:04<00:00, 759.96it/s]

# %%
# %%time
adata.raw = adata
adata = adata[:, adata.var.highly_variable_features]
adata
# Out:
# CPU times: user 1.27 s, sys: 304 ms, total: 1.57 s
# Wall time: 1.57 s
# View of AnnData object with n_obs × n_vars = 203447 × 2000
#     obs: 'author', 'donor_id', 'is_primary_data', 'annotation_level_1', 'annotation_level_2', 'annotation_level_3', 'gbmap', 'method', 'stage', 'location', 'EGFR', 'MET', 'p53', 'TERT', 'ATRX', 'PTEN', 'MGMT', 'chr1p19q', 'PDGFR', 'suspension_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'tissue', 'development_stage', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'n_genes'
#     var: 'mt', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'X_approximate_distribution', 'batch_condition', 'default_embedding', 'hvg', 'schema_version', 'title', 'log1p'
#     obsm: 'X_umap'
#     layers: 'counts', 'recover_counts'

# %%
# %%time
ov.pp.scale(adata)
adata
# Out:
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# CPU times: user 14.5 s, sys: 2.87 s, total: 17.3 s
# Wall time: 16.7 s
# AnnData object with n_obs × n_vars = 203447 × 2000
#     obs: 'author', 'donor_id', 'is_primary_data', 'annotation_level_1', 'annotation_level_2', 'annotation_level_3', 'gbmap', 'method', 'stage', 'location', 'EGFR', 'MET', 'p53', 'TERT', 'ATRX', 'PTEN', 'MGMT', 'chr1p19q', 'PDGFR', 'suspension_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'tissue', 'development_stage', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'n_genes'
#     var: 'mt', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'X_approximate_distribution', 'batch_condition', 'default_embedding', 'hvg', 'schema_version', 'title', 'log1p'
#     obsm: 'X_umap'
#     layers: 'counts', 'recover_counts', 'scaled'

# %%
# %%time
ov.pp.pca(adata,layer='scaled',n_pcs=50)
adata
# Out:
# computing PCA
#     with n_comps=50
#     finished (0:00:22)
# CPU times: user 2min 38s, sys: 5min 50s, total: 8min 28s
# Wall time: 22.1 s
# AnnData object with n_obs × n_vars = 203447 × 2000
#     obs: 'author', 'donor_id', 'is_primary_data', 'annotation_level_1', 'annotation_level_2', 'annotation_level_3', 'gbmap', 'method', 'stage', 'location', 'EGFR', 'MET', 'p53', 'TERT', 'ATRX', 'PTEN', 'MGMT', 'chr1p19q', 'PDGFR', 'suspension_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'tissue', 'development_stage', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'n_genes'
#     var: 'mt', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'X_approximate_distribution', 'batch_condition', 'default_embedding', 'hvg', 'schema_version', 'title', 'log1p', 'pca', 'scaled|original|pca_var_ratios', 'scaled|original|cum_sum_eigenvalues'
#     obsm: 'X_umap', 'X_pca', 'scaled|original|X_pca'
#     varm: 'PCs', 'scaled|original|pca_loadings'
#     layers: 'counts', 'recover_counts', 'scaled'

# %%
# %%time
ov.pp.neighbors(adata, n_neighbors=15, n_pcs=50,
               use_rep='scaled|original|X_pca')
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:44)
# CPU times: user 45.3 s, sys: 1.16 s, total: 46.4 s
# Wall time: 44.9 s

# %%
# %%time
ov.pp.umap(adata)
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm)
#     'umap', UMAP parameters (adata.uns) (0:03:36)
# CPU times: user 10min 30s, sys: 6min 55s, total: 17min 25s
# Wall time: 3min 36s

# %%
ov.pl.embedding(adata,
                basis='X_umap',
                color='CST3',
                frameon='small')

# %%
adata_raw=adata.raw.to_adata()
ov.pp.score_genes_cell_cycle(adata_raw,species='human')
# Out:
# calculating cell cycle phase
# computing score 'S_score'
# WARNING: genes are not in var_names and ignored: Index(['MLF1IP'], dtype='object')
#     finished: added
#     'S_score', score of gene set (adata.obs).
#     686 total control genes are used. (0:00:07)
# computing score 'G2M_score'
# WARNING: genes are not in var_names and ignored: Index(['FAM64A', 'HN1'], dtype='object')
#     finished: added
#     'G2M_score', score of gene set (adata.obs).
#     729 total control genes are used. (0:00:07)
# -->     'phase', cell cycle phase (adata.obs)

# %%
ov.pl.embedding(adata_raw,
                basis='X_umap',
                color='phase',
                frameon='small')

# %%
ov.pp.leiden(adata,resolution=1)
# Out:
# running Leiden clustering
#     finished: found 47 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:03:04)

# %%
ov.pl.embedding(adata,
                basis='X_umap',
                color=['leiden', 'CST3', 'PTPRC'],
                frameon='small',wspace=0.5)

# %%
ov.pl.embedding(adata,
                basis='X_umap',
                color=['leiden', 'donor_id'],
                frameon='small',wspace=0.5)

# %%
adata.write("/home/lugli/spuccio/Projects/SP039/GBmap/Abdelfattah2022_Part1.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 203447 × 2000
#     obs: 'author', 'donor_id', 'is_primary_data', 'annotation_level_1', 'annotation_level_2', 'annotation_level_3', 'gbmap', 'method', 'stage', 'location', 'EGFR', 'MET', 'p53', 'TERT', 'ATRX', 'PTEN', 'MGMT', 'chr1p19q', 'PDGFR', 'suspension_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'tissue', 'development_stage', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'n_genes', 'leiden'
#     var: 'mt', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'X_approximate_distribution', 'batch_condition', 'default_embedding', 'hvg', 'schema_version', 'title', 'log1p', 'pca', 'scaled|original|pca_var_ratios', 'scaled|original|cum_sum_eigenvalues', 'neighbors', 'umap', 'leiden', 'leiden_colors', 'donor_id_colors'
#     obsm: 'X_umap', 'X_pca', 'scaled|original|X_pca'
#     varm: 'PCs', 'scaled|original|pca_loadings'
#     layers: 'counts', 'recover_counts', 'scaled'
#     obsp: 'distances', 'connectivities'
