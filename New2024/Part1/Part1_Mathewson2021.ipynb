# %%
import scanpy as sc
import omicverse as ov
ov.plot_set()
# Out:
#    ____            _     _    __
#   / __ \____ ___  (_)___| |  / /__  _____________
#  / / / / __ `__ \/ / ___/ | / / _ \/ ___/ ___/ _ \
# / /_/ / / / / / / / /__ | |/ /  __/ /  (__  )  __/
# \____/_/ /_/ /_/_/\___/ |___/\___/_/  /____/\___/
#
# Version: 1.6.11, Tutorials: https://omicverse.readthedocs.io/
# Dependency error: The 'phate>=1.0' distribution was not found and is required by the application

# %%
adata = sc.read("/home/lugli/spuccio/Projects/SP039/GBmap/Mathewson2021_Part1.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 24310 × 26355
#     obs: 'author', 'donor_id', 'is_primary_data', 'annotation_level_1', 'annotation_level_2', 'annotation_level_3', 'gbmap', 'method', 'stage', 'location', 'EGFR', 'MET', 'p53', 'TERT', 'ATRX', 'PTEN', 'MGMT', 'chr1p19q', 'PDGFR', 'suspension_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'tissue', 'development_stage'
#     uns: 'X_approximate_distribution', 'batch_condition', 'default_embedding', 'hvg', 'schema_version', 'title'
#     obsm: 'X_umap'

# %%
adata.var_names_make_unique()
adata.obs_names_make_unique()

# %%
# %%time
adata=ov.pp.qc(adata,
              tresh={'mito_perc': 0.3, 'nUMIs': 500, 'detected_genes': 250},
               doublets_method='sccomposite',
              batch_key=None)
adata
# Out:
# CPU mode activated
# Calculate QC metrics
# End calculation of QC metrics.
# Original cell number: 24310
# !!!It should be noted that the `sccomposite` will remove more cells than             `scrublet`!!!
# Begin of post doublets removal and QC plot using `sccomposite`
# Cuda is not available; Fitting the COMPOSITE model on RNA modality
# Warning: too few stable features to provide reliable inference.
# The RNA modality goodness-of-fit score is less than 3;         The model may not fit the data well
# The RNA modality goodness-of-fit score is: 2.411642343926179
# <3: poor fit
# 3~5: moderate fit
# >5: good fit
# Cells retained after sccomposite: 24310, 0 removed.
# End of post sccomposite removal and QC plots.
# Filters application (seurat or mads)
# Lower treshold, nUMIs: 500; filtered-out-cells:         20832
# Lower treshold, n genes: 250; filtered-out-cells:         24280
# Lower treshold, mito %: 0.3; filtered-out-cells:         0
# Filters applicated.
# Total cell filtered out with this last --mode seurat QC (and its     chosen options): 24280
# Cells retained after scrublet and seurat filtering: 30, 24280 removed.
# filtered out 971 genes that are detected in less than 3 cells
# CPU times: user 13h 38min 13s, sys: 59.5 s, total: 13h 39min 12s
# Wall time: 2h 25min 13s
# AnnData object with n_obs × n_vars = 30 × 1029
#     obs: 'author', 'donor_id', 'is_primary_data', 'annotation_level_1', 'annotation_level_2', 'annotation_level_3', 'gbmap', 'method', 'stage', 'location', 'EGFR', 'MET', 'p53', 'TERT', 'ATRX', 'PTEN', 'MGMT', 'chr1p19q', 'PDGFR', 'suspension_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'tissue', 'development_stage', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency', 'leiden', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'n_genes'
#     var: 'mt', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'X_approximate_distribution', 'batch_condition', 'default_embedding', 'hvg', 'schema_version', 'title', 'log1p', 'pca', 'scaled|original|pca_var_ratios', 'scaled|original|cum_sum_eigenvalues', 'neighbors', 'umap', 'leiden', 'leiden_colors', 'donor_id_colors'
#     obsm: 'X_umap', 'X_pca', 'scaled|original|X_pca'
#     varm: 'PCs', 'scaled|original|pca_loadings'
#     layers: 'counts', 'recover_counts', 'scaled'
#     obsp: 'distances', 'connectivities'

# %%
# %%time
adata=ov.pp.preprocess(adata,mode='shiftlog|pearson',n_HVGs=2000,
                       target_sum=50*1e4)
adata
# Out:
# Begin robust gene identification
# After filtration, 14018/26355 genes are kept.     Among 14018 genes, 12951 genes are robust.
# End of robust gene identification.
# Begin size normalization: shiftlog and HVGs selection pearson
# normalizing counts per cell. The following highly-expressed genes are not considered during normalization factor computation:
# []
#     finished (0:00:00)
# extracting highly variable genes
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'highly_variable_rank', float vector (adata.var)
#     'highly_variable_nbatches', int vector (adata.var)
#     'highly_variable_intersection', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'variances', float vector (adata.var)
#     'residual_variances', float vector (adata.var)
# Time to analyze data in cpu: 5.774468421936035 seconds.
# End of size normalization: shiftlog and HVGs selection pearson
# CPU times: user 10.7 s, sys: 1.45 s, total: 12.1 s
# Wall time: 7.14 s
# AnnData object with n_obs × n_vars = 24310 × 12951
#     obs: 'author', 'donor_id', 'is_primary_data', 'annotation_level_1', 'annotation_level_2', 'annotation_level_3', 'gbmap', 'method', 'stage', 'location', 'EGFR', 'MET', 'p53', 'TERT', 'ATRX', 'PTEN', 'MGMT', 'chr1p19q', 'PDGFR', 'suspension_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'tissue', 'development_stage', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency'
#     var: 'mt', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'X_approximate_distribution', 'batch_condition', 'default_embedding', 'hvg', 'schema_version', 'title', 'log1p'
#     obsm: 'X_umap'
#     layers: 'counts'

# %%
X_counts_recovered, size_factors_sub=ov.pp.recover_counts(adata.X, 50*1e4, 50*1e5, log_base=None, 
                                                          chunk_size=10000)
adata.layers['recover_counts']=X_counts_recovered
# Out:
# 100%|██████████| 10000/10000 [00:11<00:00, 844.23it/s]
# 100%|██████████| 10000/10000 [00:11<00:00, 837.46it/s]
# 100%|██████████| 4310/4310 [00:05<00:00, 822.42it/s]

# %%
# %%time
adata.raw = adata
adata = adata[:, adata.var.highly_variable_features]
adata
# Out:
# CPU times: user 79.4 ms, sys: 55.8 ms, total: 135 ms
# Wall time: 134 ms
# View of AnnData object with n_obs × n_vars = 24310 × 2000
#     obs: 'author', 'donor_id', 'is_primary_data', 'annotation_level_1', 'annotation_level_2', 'annotation_level_3', 'gbmap', 'method', 'stage', 'location', 'EGFR', 'MET', 'p53', 'TERT', 'ATRX', 'PTEN', 'MGMT', 'chr1p19q', 'PDGFR', 'suspension_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'tissue', 'development_stage', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency'
#     var: 'mt', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'X_approximate_distribution', 'batch_condition', 'default_embedding', 'hvg', 'schema_version', 'title', 'log1p'
#     obsm: 'X_umap'
#     layers: 'counts', 'recover_counts'

# %%
# %%time
ov.pp.scale(adata)
adata
# Out:
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# CPU times: user 1.56 s, sys: 228 ms, total: 1.79 s
# Wall time: 1.48 s
# AnnData object with n_obs × n_vars = 24310 × 2000
#     obs: 'author', 'donor_id', 'is_primary_data', 'annotation_level_1', 'annotation_level_2', 'annotation_level_3', 'gbmap', 'method', 'stage', 'location', 'EGFR', 'MET', 'p53', 'TERT', 'ATRX', 'PTEN', 'MGMT', 'chr1p19q', 'PDGFR', 'suspension_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'tissue', 'development_stage', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency'
#     var: 'mt', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'X_approximate_distribution', 'batch_condition', 'default_embedding', 'hvg', 'schema_version', 'title', 'log1p'
#     obsm: 'X_umap'
#     layers: 'counts', 'recover_counts', 'scaled'

# %%
# %%time
ov.pp.pca(adata,layer='scaled',n_pcs=50)
adata
# Out:
# computing PCA
#     with n_comps=50
#     finished (0:00:22)
# CPU times: user 1min 15s, sys: 6min 47s, total: 8min 3s
# Wall time: 22.9 s
# AnnData object with n_obs × n_vars = 24310 × 2000
#     obs: 'author', 'donor_id', 'is_primary_data', 'annotation_level_1', 'annotation_level_2', 'annotation_level_3', 'gbmap', 'method', 'stage', 'location', 'EGFR', 'MET', 'p53', 'TERT', 'ATRX', 'PTEN', 'MGMT', 'chr1p19q', 'PDGFR', 'suspension_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'tissue', 'development_stage', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency'
#     var: 'mt', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'X_approximate_distribution', 'batch_condition', 'default_embedding', 'hvg', 'schema_version', 'title', 'log1p', 'pca', 'scaled|original|pca_var_ratios', 'scaled|original|cum_sum_eigenvalues'
#     obsm: 'X_umap', 'X_pca', 'scaled|original|X_pca'
#     varm: 'PCs', 'scaled|original|pca_loadings'
#     layers: 'counts', 'recover_counts', 'scaled'

# %%
# %%time
ov.pp.neighbors(adata, n_neighbors=15, n_pcs=50,
               use_rep='scaled|original|X_pca')
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:35)
# CPU times: user 33.4 s, sys: 992 ms, total: 34.3 s
# Wall time: 35.3 s

# %%
# %%time
ov.pp.umap(adata)
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm)
#     'umap', UMAP parameters (adata.uns) (0:00:28)
# CPU times: user 29.6 s, sys: 28 s, total: 57.6 s
# Wall time: 28.3 s

# %%
ov.pl.embedding(adata,
                basis='X_umap',
                color='CST3',
                frameon='small')

# %%
adata_raw=adata.raw.to_adata()
ov.pp.score_genes_cell_cycle(adata_raw,species='human')
# Out:
# calculating cell cycle phase
# computing score 'S_score'
# WARNING: genes are not in var_names and ignored: Index(['MLF1IP', 'RAD51'], dtype='object')
#     finished: added
#     'S_score', score of gene set (adata.obs).
#     773 total control genes are used. (0:00:00)
# computing score 'G2M_score'
# WARNING: genes are not in var_names and ignored: Index(['FAM64A', 'HN1'], dtype='object')
#     finished: added
#     'G2M_score', score of gene set (adata.obs).
#     854 total control genes are used. (0:00:00)
# -->     'phase', cell cycle phase (adata.obs)

# %%
ov.pl.embedding(adata_raw,
                basis='X_umap',
                color='phase',
                frameon='small')

# %%
ov.pp.leiden(adata,resolution=1)
# Out:
# running Leiden clustering
#     finished: found 18 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:24)

# %%
ov.pl.embedding(adata,
                basis='X_umap',
                color=['leiden', 'CST3', 'PTPRC'],
                frameon='small',wspace=0.5)

# %%
ov.pl.embedding(adata,
                basis='X_umap',
                color=['leiden', 'donor_id'],
                frameon='small',wspace=0.5)

# %%
adata.write("/home/lugli/spuccio/Projects/SP039/GBmap/Mathewson2021_Part1.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 24310 × 2000
#     obs: 'author', 'donor_id', 'is_primary_data', 'annotation_level_1', 'annotation_level_2', 'annotation_level_3', 'gbmap', 'method', 'stage', 'location', 'EGFR', 'MET', 'p53', 'TERT', 'ATRX', 'PTEN', 'MGMT', 'chr1p19q', 'PDGFR', 'suspension_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'tissue', 'development_stage', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'sccomposite_doublet', 'sccomposite_consistency', 'leiden'
#     var: 'mt', 'n_cells', 'percent_cells', 'robust', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable_features'
#     uns: 'X_approximate_distribution', 'batch_condition', 'default_embedding', 'hvg', 'schema_version', 'title', 'log1p', 'pca', 'scaled|original|pca_var_ratios', 'scaled|original|cum_sum_eigenvalues', 'neighbors', 'umap', 'leiden', 'leiden_colors', 'donor_id_colors'
#     obsm: 'X_umap', 'X_pca', 'scaled|original|X_pca'
#     varm: 'PCs', 'scaled|original|pca_loadings'
#     layers: 'counts', 'recover_counts', 'scaled'
#     obsp: 'distances', 'connectivities'
